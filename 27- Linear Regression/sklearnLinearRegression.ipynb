# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
df = pd.read_csv('height_weight_dataset.csv')
df.head()
# Out:
#    Height  Weight
# 0     188      92
# 1     178      76
# 2     164      73
# 3     192      98
# 4     157      63

# %%
plt.scatter(df['Height'], df['Weight'])
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.921922
# Weight  0.921922  1.000000

# %%
sns.pairplot(df)

# %%
X = df[['Weight']]
y = df['Height']

# %%
y
# Out:
# 0      188
# 1      178
# 2      164
# 3      192
# 4      157
#       ...
# 195    186
# 196    182
# 197    191
# 198    193
# 199    173
# Name: Height, Length: 200, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-2.40030119e-01],
#        [-1.81333678e+00],
#        [-3.61053708e-01],
#        [-3.00541913e-01],
#        [ 1.57532372e+00],
#        [ 1.15174116e+00],
#        [-5.84947348e-02],
#        [-1.02668345e+00],
#        [ 4.86111417e-01],
#        [ 6.07135006e-01],
#        [-7.84636271e-01],
#        [ 3.04576033e-01],
#        [-5.42589092e-01],
#        [ 8.49182185e-01],
#        [ 2.01705982e-03],
#        [ 1.69634731e+00],
#        [-5.42589092e-01],
#        [ 1.27276475e+00],
#        [-2.40030119e-01],
#        [-1.57128960e+00],
#        [ 4.25599622e-01],
#        [-6.63612681e-01],
#        [ 3.65087828e-01],
#        [ 4.86111417e-01],
#        [-1.93436037e+00],
#        [-1.19006529e-01],
#        [-4.82077297e-01],
#        [ 1.15174116e+00],
#        [-4.21565503e-01],
#        [ 1.83552444e-01],
#        [-1.26873063e+00],
#        [-6.03100887e-01],
#        [ 1.21225295e+00],
#        [ 1.03071757e+00],
#        [-7.24124476e-01],
#        [-1.14770704e+00],
#        [ 1.15174116e+00],
#        [-1.08719524e+00],
#        [ 3.04576033e-01],
#        [-1.08719524e+00],
#        [ 2.01705982e-03],
#        [ 9.09693980e-01],
#        [ 1.09122936e+00],
#        [ 1.23040649e-01],
#        [ 1.83552444e-01],
#        [ 1.03071757e+00],
#        [ 2.05941808e+00],
#        [ 6.07135006e-01],
#        [ 8.49182185e-01],
#        [ 1.81737090e+00]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regression.predict(X_train),color='blue')

# %%
y_pred = regression.predict(X_test)

# %%
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Index')
plt.ylabel('Height')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score

print('Mean Squared Error:', mean_squared_error(y_test,y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test,y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:', rmse)
print('R2 Score:', r2_score(y_test,y_pred))
# Out:
# Mean Squared Error: 30.627919998364074
# Mean Absolute Error: 4.729931152329846
# Root Mean Squared Error: 5.534249723166102
# R2 Score: 0.8328739556048372

# %%
stds = scaler.transform([[60]])
regression.predict(stds)
# Out:
# array([173.76])
