# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    ' I am a developer ',
    'understanding the meaning of words',
    'your videos are good'
]

# %%
voc_size = 10000

# %%
one_hot_rep = [one_hot(words,voc_size) for words in sent]

# %%
one_hot_rep
# Out:
# [[7355, 7908, 901, 3982],
#  [7355, 7908, 901, 5034],
#  [7355, 6591, 901, 5860],
#  [8009, 3620, 2836, 4807],
#  [5529, 7355, 2010, 901, 7166],
#  [6220, 87, 2659, 1712]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sentence_length = 8
embedded_docs = pad_sequences(one_hot_rep,padding='pre',maxlen=sentence_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 7355, 7908,  901, 3982],
#        [   0,    0,    0,    0, 7355, 7908,  901, 5034],
#        [   0,    0,    0,    0, 7355, 6591,  901, 5860],
#        [   0,    0,    0,    0, 8009, 3620, 2836, 4807],
#        [   0,    0,    0, 5529, 7355, 2010,  901, 7166],
#        [   0,    0,    0,    0, 6220,   87, 2659, 1712]])

# %%
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sentence_length))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step
# array([[[ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [-0.01802689,  0.00966452,  0.01209838, -0.03922789,
#          -0.00860142,  0.0142053 ,  0.03984067, -0.04667875,
#           0.02499421,  0.01460523],
#         [ 0.0004182 , -0.02646909, -0.04390517,  0.04066527,
#           0.0245399 , -0.02658997, -0.01498228, -0.01696939,
#          -0.03949237,  0.01752504],
#         [ 0.04505055,  0.04444224,  0.00492326, -0.01414454,
#           0.03515079,  0.04479008,  0.03901483,  0.03879045,
#          -0.03616599, -0.04674865],
#         [-0.01117691, -0.01213304, -0.02640571,  0.00029014,
#           0.03887809, -0.03501599,  0.0015463 , -0.02746901,
#           0.0337336 , -0.02320989]],
#
#        [[ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [-0.01802689,  0.00966452,  0.01209838, -0.03922789,
#          -0.00860142,  0.0142053 ,  0.03984067, -0.04667875,
#           0.02499421,  0.01460523],
#         [ 0.0004182 , -0.02646909, -0.04390517,  0.04066527,
#           0.0245399 , -0.02658997, -0.01498228, -0.01696939,
#          -0.03949237,  0.01752504],
#         [ 0.04505055,  0.04444224,  0.00492326, -0.01414454,
#           0.03515079,  0.04479008,  0.03901483,  0.03879045,
#          -0.03616599, -0.04674865],
#         [ 0.0238374 , -0.02685208,  0.0228806 ,  0.00056682,
#          -0.00791467, -0.01203113, -0.00939607, -0.0028792 ,
#          -0.02043178,  0.028595  ]],
#
#        [[ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [-0.01802689,  0.00966452,  0.01209838, -0.03922789,
#          -0.00860142,  0.0142053 ,  0.03984067, -0.04667875,
#           0.02499421,  0.01460523],
#         [-0.02783967, -0.0005408 , -0.00274693, -0.01311681,
#           0.04773224, -0.02717307,  0.01915108, -0.02326372,
#          -0.03667183,  0.02656129],
#         [ 0.04505055,  0.04444224,  0.00492326, -0.01414454,
#           0.03515079,  0.04479008,  0.03901483,  0.03879045,
#          -0.03616599, -0.04674865],
#         [-0.02619132, -0.02955427, -0.00442085,  0.0151975 ,
#           0.0433288 ,  0.0173496 ,  0.04497569,  0.01907179,
#           0.041524  , -0.01627497]],
#
#        [[ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [-0.04542429, -0.02550436,  0.00979396, -0.01742242,
#           0.01759923, -0.01420302, -0.03229063, -0.04531434,
#          -0.00974308,  0.03700024],
#         [-0.03618718, -0.01686156,  0.02709671, -0.01419798,
#           0.04613202,  0.04820296, -0.04669465,  0.02745515,
#           0.0390789 ,  0.03197895],
#         [ 0.01763782, -0.01318836,  0.0478447 ,  0.0169342 ,
#          -0.00999545, -0.03804097, -0.03612628,  0.0135452 ,
#          -0.0133668 , -0.01944321],
#         [ 0.04497702, -0.03090891, -0.03243331, -0.03392518,
#           0.02309103,  0.02660261,  0.03240794, -0.02808866,
#          -0.04272756,  0.02401071]],
#
#        [[ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [-0.02496377, -0.00490644, -0.04591131,  0.01250544,
#           0.01319982, -0.03731624, -0.02971088, -0.03064419,
#          -0.0394951 ,  0.04892682],
#         [-0.01802689,  0.00966452,  0.01209838, -0.03922789,
#          -0.00860142,  0.0142053 ,  0.03984067, -0.04667875,
#           0.02499421,  0.01460523],
#         [ 0.01748511,  0.0054419 ,  0.02769785, -0.01466323,
#          -0.01381528,  0.02774744, -0.01629008,  0.02222652,
#          -0.01929864,  0.01328094],
#         [ 0.04505055,  0.04444224,  0.00492326, -0.01414454,
#           0.03515079,  0.04479008,  0.03901483,  0.03879045,
#          -0.03616599, -0.04674865],
#         [ 0.02355197, -0.034404  , -0.01643776,  0.03509918,
#           0.01100242, -0.00527096,  0.01699407, -0.02176191,
#           0.03907225, -0.03490808]],
#
#        [[ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513,
#          -0.00707458,  0.04991651,  0.02192607,  0.02347001,
#           0.02427829, -0.01217804],
#         [-0.04902567,  0.00879899, -0.02872294,  0.04622436,
#           0.04540557, -0.04997932, -0.01422592, -0.01218672,
#           0.03599617,  0.03428085],
#         [ 0.03910241, -0.02011141,  0.02543099,  0.01391361,
#          -0.04600283,  0.01711604, -0.0267589 , -0.0219033 ,
#           0.02320268,  0.01526214],
#         [-0.02772738,  0.01377758,  0.01595802,  0.03898961,
#          -0.01100216,  0.01437582, -0.00586077,  0.02218531,
#          -0.0118195 ,  0.04406125],
#         [ 0.03946421,  0.00698084, -0.0483347 ,  0.01885993,
#          -0.01531981, -0.01002609, -0.0129472 ,  0.03673844,
#          -0.03606712,  0.0495216 ]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7355, 7908,  901, 3982])

# %%
model.predict(embedded_docs)[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# array([[ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513, -0.00707458,
#          0.04991651,  0.02192607,  0.02347001,  0.02427829, -0.01217804],
#        [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513, -0.00707458,
#          0.04991651,  0.02192607,  0.02347001,  0.02427829, -0.01217804],
#        [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513, -0.00707458,
#          0.04991651,  0.02192607,  0.02347001,  0.02427829, -0.01217804],
#        [ 0.04866843, -0.0460887 ,  0.02519572,  0.01172513, -0.00707458,
#          0.04991651,  0.02192607,  0.02347001,  0.02427829, -0.01217804],
#        [-0.01802689,  0.00966452,  0.01209838, -0.03922789, -0.00860142,
#          0.0142053 ,  0.03984067, -0.04667875,  0.02499421,  0.01460523],
#        [ 0.0004182 , -0.02646909, -0.04390517,  0.04066527,  0.0245399 ,
#         -0.02658997, -0.01498228, -0.01696939, -0.03949237,  0.01752504],
#        [ 0.04505055,  0.04444224,  0.00492326, -0.01414454,  0.03515079,
#          0.04479008,  0.03901483,  0.03879045, -0.03616599, -0.04674865],
#        [-0.01117691, -0.01213304, -0.02640571,  0.00029014,  0.03887809,
#         -0.03501599,  0.0015463 , -0.02746901,  0.0337336 , -0.02320989]],
#       dtype=float32)
